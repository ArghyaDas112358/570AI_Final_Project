# %%
# python based
import tensorflow as tf
from pathlib import Path
import time
import shutil
import random
import os
import pandas as pd
import numpy as np
from tensorflow.keras.optimizers import Adam, Nadam
import matplotlib.pyplot as plt

# custom 
from loss import *
from models import *
from dataloaders import utils
from dataloaders import OptimizedDataGenerator as DG
# Out:
# 2024-11-26 08:24:29.851355: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-26 08:24:29.851426: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-26 08:24:29.852915: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-26 08:24:29.861091: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-26 08:24:30.828468: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
print("Num CPU:", os.cpu_count())
print(utils.check_GPU())
# Out:
# Num CPU: 128
# 1 Physical GPUs, 1 Logical GPUs
# None
# 2024-11-26 08:24:33.529392: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 33857 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB MIG 7g.40gb, pci bus id: 0000:21:00.0, compute capability: 8.0

# %%
def load_sensor_geometries(file_path):
    sensor_geometries = {}
    with open(file_path, 'r') as file:
        for line in file:
            line = line.strip()
            if line and not line.startswith("#"):  # Skip comments and empty lines
                dataset_type, geometry = line.split(": ")
                sensor_geometries[dataset_type.strip()] = geometry.strip()
    return sensor_geometries
sensor_geometries = load_sensor_geometries('types.txt')

# %%
dataset_name = 'dataset2s'
type = 'type6'
print(sensor_geometries[f'{dataset_name} {type}'])
# Out:
# 100 um x 25 um x 100 um sensor @ 100V

# %%
# dataset_path = '/depot/cms/users/dkondra/smart-pixels/dataset8/unflipped-positive'
dataset_path = f'/depot/cms/users/das214/{dataset_name}/{type}/unflipped/'
data_directory_path = os.path.join(dataset_path, 'recon3D/')
labels_directory_path = os.path.join(dataset_path, 'labels/')

data_files_path_list = [os.path.join(data_directory_path, f) for f in os.listdir(data_directory_path)]
labels_files_path_list = [os.path.join(labels_directory_path, f) for f in os.listdir(labels_directory_path)]

data_files_path_list = np.sort(data_files_path_list)
labels_files_path_list = np.sort(labels_files_path_list)

print(data_directory_path)
print(labels_directory_path)
print(len(data_files_path_list))
print(len(labels_files_path_list))
# Out:
# /depot/cms/users/das214/dataset2s/type6/unflipped/recon3D/
# /depot/cms/users/das214/dataset2s/type6/unflipped/labels/
# 41
# 41

# %%
output_directory = Path("./").resolve()

batch_size = 5000
val_batch_size = 5000
train_file_size = 35
val_file_size = 6

# batch_size = 500
# val_batch_size = 500
# train_file_size = 20 
# val_file_size = 6

# %%
os.makedirs(output_directory, exist_ok=True)
print(output_directory)
# Out:
# /home/das214/SmartPix/dataset2s

# %%
# create tf records directory (random)
stamp = '%08x' % random.randrange(16**8)
stamp = 1
tfrecords_dir_train = Path(output_directory, f"tfrecords_train_{stamp}").resolve()
tfrecords_dir_validation = Path(output_directory, f"tfrecords_validation_{stamp}").resolve()

# Path where the TFRecord files will be saved (deterministic)
tfrecords_dir_train = f'/depot/cms/users/das214/{dataset_name}/{type}/unflipped/TFR_20t_train'
tfrecords_dir_validation = f'/depot/cms/users/das214/{dataset_name}/{type}/unflipped/TFR_20t_val'

print(tfrecords_dir_train)
print(tfrecords_dir_validation)
# clean up tf records
# utils.safe_remove_directory(tfrecords_dir_train)
# utils.safe_remove_directory(tfrecords_dir_validation)
# Out:
# /depot/cms/users/das214/dataset2s/type6/unflipped/TFR_20t_train
# /depot/cms/users/das214/dataset2s/type6/unflipped/TFR_20t_val

# %%
# # validation generator

# # Caution: If you want to load older TFRecord files dont run like this instead use `load_from_tfrecords_dir`
# #       Or else if there exist and data at `tfrecords_dir` will be removed.

# start_time = time.time()
# validation_generator = DG.OptimizedDataGenerator(
#     data_directory_path = data_directory_path,
#     labels_directory_path = labels_directory_path,
#     is_directory_recursive = False,
#     file_type = "parquet",
#     data_format = "3D",
#     batch_size = val_batch_size,
#     file_count = val_file_size,
#     to_standardize= True,
#     include_y_local= True, 
#     labels_list = ['x-midplane','y-midplane','cotAlpha','cotBeta'],
#     input_shape = (20,13,21), # (2,13,21),
#     transpose = (0,2,3,1),
#     shuffle = False, 
#     files_from_end=True,

#     tfrecords_dir = tfrecords_dir_validation,
#     use_time_stamps =  -1, # [0, 19],
#     max_workers = 2 # Don't make this too large (will use up all RAM)
# )

# print("--- Validation generator %s seconds ---" % (time.time() - start_time))

# %%
# # training generator

# # Caution: If you want to load older TFRecord files dont run like this instead use `load_from_tfrecords_dir`
# #       Or else if there exist and data at `tfrecords_dir` will be removed.


# start_time = time.time()
# training_generator = DG.OptimizedDataGenerator(
#     data_directory_path = data_directory_path,
#     labels_directory_path = labels_directory_path,
#     is_directory_recursive = False,
#     file_type = "parquet",
#     data_format = "3D",
#     batch_size = batch_size,
#     file_count = train_file_size,
#     to_standardize= True,
#     include_y_local= True,
#     labels_list = ['x-midplane','y-midplane','cotAlpha','cotBeta'],
#     input_shape = (20,13,21), # (2,13,21),
#     transpose = (0,2,3,1),
#     shuffle = False, # True 

#     tfrecords_dir = tfrecords_dir_train,
#     use_time_stamps =  -1, # [0, 19],
#     max_workers = 2 # Don't make this too large (will use up all RAM)
# )
# print("--- Training generator %s seconds ---" % (time.time() - start_time))

# %%
# This cell can be commented out entirely
# This cell shows the implementation of how to load TFRecord files if they are already initialized earlier
# Letting the user load from older files saving time (from preprocessing and saving)

training_generator = DG.OptimizedDataGenerator(
    load_from_tfrecords_dir = tfrecords_dir_train,
    include_y_local= True,
    shuffle = True,
    seed = 13,
    quantize = True
)

validation_generator = DG.OptimizedDataGenerator(
    load_from_tfrecords_dir = tfrecords_dir_validation, 
    include_y_local= True,
    shuffle = True,
    seed = 13,
    quantize = True
)
# Out:
# WARNING:root:Quantization is True in data generator. This may affect model performance.
# WARNING:root:Quantization is True in data generator. This may affect model performance.

# %%
def CreateModel(shape, n_filters, pool_size):
    x_base = x_in = Input(shape, name="X_input")  # Main input (X)
    y_local_in = Input(shape=(1,), name="y_local_input")  # y_local input
    
    stack = conv_network(x_base, n_filters)
    stack = AveragePooling2D(
        pool_size=(pool_size, pool_size), 
        strides=None, 
        padding="valid", 
        data_format=None,        
    )(stack)
    stack = QActivation("quantized_bits(8, 0, alpha=1)")(stack)
    stack = Flatten()(stack)
    # stack = Concatenate()([stack, y_local_in])
    stack = var_network(stack, hidden=16, output=14)
    model = Model(inputs=x_in, outputs=stack)
    return model

# %%
input_shape = (13, 21, 20)
model = CreateModel(input_shape, n_filters=5, pool_size=3)
model.summary()
# Out:
# 2024-11-26 08:24:34.159023: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  X_input (InputLayer)        [(None, 13, 21, 20)]      0
#
#  q_separable_conv2d (QSepar  (None, 11, 19, 5)         285
#  ableConv2D)
#
#  q_activation (QActivation)  (None, 11, 19, 5)         0
#
#  q_conv2d (QConv2D)          (None, 11, 19, 5)         30
#
#  q_activation_1 (QActivatio  (None, 11, 19, 5)         0
#  n)
#
#  average_pooling2d (Average  (None, 3, 6, 5)           0
#  Pooling2D)
#
#  q_activation_2 (QActivatio  (None, 3, 6, 5)           0
#  n)
#
#  flatten (Flatten)           (None, 90)                0
#
#  flatten_1 (Flatten)         (None, 90)                0
#
#  q_dense (QDense)            (None, 16)                1456
#
#  q_activation_3 (QActivatio  (None, 16)                0
#  n)
#
#  q_dense_1 (QDense)          (None, 16)                272
#
#  q_activation_4 (QActivatio  (None, 16)                0
#  n)
#
#  q_dense_2 (QDense)          (None, 14)                238
#
# =================================================================
# Total params: 2281 (8.91 KB)
# Trainable params: 2281 (8.91 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Nadam(learning_rate=1e-3),
    loss=custom_loss
)

# %%
fingerprint = '%08x' % random.randrange(16**8)
os.makedirs("trained_models", exist_ok=True)
base_dir = f'./trained_models/{type}/model-{fingerprint}-checkpoints'
os.makedirs(base_dir, exist_ok=True)  
checkpoint_filepath = base_dir + '/weights.{epoch:02d}-t{loss:.2f}-v{val_loss:.2f}.hdf5'

# %%
print(fingerprint)
# Out:
# c8fe3c7d

# %%
from tensorflow.keras.callbacks import CSVLogger, EarlyStopping, ModelCheckpoint, Callback

early_stopping_patience = 50

class CustomModelCheckpoint(ModelCheckpoint):
    def on_epoch_end(self, epoch, logs=None):
        super().on_epoch_end(epoch, logs)
        checkpoints = [f for f in os.listdir(base_dir) if f.startswith('weights')]
        if len(checkpoints) > 1:
            checkpoints.sort()
            for checkpoint in checkpoints[:-1]:
                os.remove(os.path.join(base_dir, checkpoint))

es = EarlyStopping(patience=early_stopping_patience, restore_best_weights=True)

mcp = CustomModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_loss',
    save_best_only=True,
    save_freq='epoch',
    verbose=1
)

csv_logger = CSVLogger(f'{base_dir}/training_log.csv', append=True)

# %%
# Fetch the first batch from the generator
X_batch, y_batch = training_generator.__getitem__(0)

# %%
# Check if X_batch is a list (since include_y_local=True)
if isinstance(X_batch, list):
    X, y_local = X_batch  # Unpack the list into X and y_local
    print("X shape:", X.shape)        # Should be [batch_size, 13, 21, 2]
    print("y_local shape:", y_local.shape)  # Should be [batch_size, 1] or [batch_size]
else:
    X = X_batch  # If include_y_local=False, it's just X
    print("X shape:", X.shape)  # Just X data shape

# Print the shape of the labels (y)
print("y_batch shape:", y_batch.shape)  # Should always be [batch_size, 4]
# Out:
# X shape: (5000, 13, 21, 20)
# y_batch shape: (5000, 4)

# %%
model.fit(
    x=training_generator,
    validation_data=validation_generator,
    callbacks=[es, mcp, csv_logger],
    epochs=1000,
    shuffle=False,
    verbose=1
)
# Out:
# Epoch 1/1000
# 2024-11-26 08:24:39.436485: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2024-11-26 08:24:39.597802: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-11-26 08:24:40.013778: I tensorflow/core/util/cuda_solvers.cc:179] Creating GpuSolver handles for stream 0x564edfd268b0
# 2024-11-26 08:24:41.743622: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f8133b52d70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-11-26 08:24:41.743678: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100-PCIE-40GB MIG 7g.40gb, Compute Capability 8.0
# 2024-11-26 08:24:41.755380: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732605881.901755 1634181 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 349/349 [==============================] - ETA: 0s - loss: 12709.6953
# Epoch 1: val_loss improved from inf to -3928.79443, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.01-t12709.70-v-3928.79.hdf5
# 349/349 [==============================] - 88s 234ms/step - loss: 12709.6953 - val_loss: -3928.7944
# Epoch 2/1000
# 349/349 [==============================] - ETA: 0s - loss: -7741.3252
# Epoch 2: val_loss improved from -3928.79443 to -9787.60645, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.02-t-7741.33-v-9787.61.hdf5
# 349/349 [==============================] - 76s 218ms/step - loss: -7741.3252 - val_loss: -9787.6064
# Epoch 3/1000
# 349/349 [==============================] - ETA: 0s - loss: -11901.4062
# Epoch 3: val_loss improved from -9787.60645 to -13747.80957, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.03-t-11901.41-v-13747.81.hdf5
# 349/349 [==============================] - 78s 222ms/step - loss: -11901.4062 - val_loss: -13747.8096
# Epoch 4/1000
# 349/349 [==============================] - ETA: 0s - loss: -13935.3740
# Epoch 4: val_loss improved from -13747.80957 to -14217.14941, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.04-t-13935.37-v-14217.15.hdf5
# 349/349 [==============================] - 75s 215ms/step - loss: -13935.3740 - val_loss: -14217.1494
# Epoch 5/1000
# 349/349 [==============================] - ETA: 0s - loss: -14149.1855
# Epoch 5: val_loss improved from -14217.14941 to -15821.27734, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.05-t-14149.19-v-15821.28.hdf5
# 349/349 [==============================] - 74s 212ms/step - loss: -14149.1855 - val_loss: -15821.2773
# Epoch 6/1000
# 349/349 [==============================] - ETA: 0s - loss: -15299.7754
# Epoch 6: val_loss improved from -15821.27734 to -16344.02246, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.06-t-15299.78-v-16344.02.hdf5
# 349/349 [==============================] - 73s 210ms/step - loss: -15299.7754 - val_loss: -16344.0225
# Epoch 7/1000
# 349/349 [==============================] - ETA: 0s - loss: -15908.9805
# Epoch 7: val_loss improved from -16344.02246 to -16420.72070, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.07-t-15908.98-v-16420.72.hdf5
# 349/349 [==============================] - 74s 212ms/step - loss: -15908.9805 - val_loss: -16420.7207
# Epoch 8/1000
# 349/349 [==============================] - ETA: 0s - loss: -15870.2529
# Epoch 8: val_loss improved from -16420.72070 to -16934.58398, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.08-t-15870.25-v-16934.58.hdf5
# 349/349 [==============================] - 75s 214ms/step - loss: -15870.2529 - val_loss: -16934.5840
# Epoch 9/1000
# 349/349 [==============================] - ETA: 0s - loss: -15869.2666
# Epoch 9: val_loss improved from -16934.58398 to -17430.62305, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.09-t-15869.27-v-17430.62.hdf5
# 349/349 [==============================] - 81s 233ms/step - loss: -15869.2666 - val_loss: -17430.6230
# Epoch 10/1000
# 349/349 [==============================] - ETA: 0s - loss: -16956.0352
# Epoch 10: val_loss did not improve from -17430.62305
# 349/349 [==============================] - 76s 217ms/step - loss: -16956.0352 - val_loss: -15912.0146
# Epoch 11/1000
# 349/349 [==============================] - ETA: 0s - loss: -17198.0254
# Epoch 11: val_loss did not improve from -17430.62305
# 349/349 [==============================] - 88s 253ms/step - loss: -17198.0254 - val_loss: -16103.5254
# Epoch 12/1000
# 349/349 [==============================] - ETA: 0s - loss: -17151.3164
# Epoch 12: val_loss did not improve from -17430.62305
# 349/349 [==============================] - 102s 292ms/step - loss: -17151.3164 - val_loss: -15290.5879
# Epoch 13/1000
# 349/349 [==============================] - ETA: 0s - loss: -17211.2832
# Epoch 13: val_loss improved from -17430.62305 to -18226.67773, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.13-t-17211.28-v-18226.68.hdf5
# 349/349 [==============================] - 112s 322ms/step - loss: -17211.2832 - val_loss: -18226.6777
# Epoch 14/1000
# 349/349 [==============================] - ETA: 0s - loss: -16961.1426
# Epoch 14: val_loss did not improve from -18226.67773
# 349/349 [==============================] - 112s 320ms/step - loss: -16961.1426 - val_loss: -18207.7930
# Epoch 15/1000
# 349/349 [==============================] - ETA: 0s - loss: -18020.5625
# Epoch 15: val_loss did not improve from -18226.67773
# 349/349 [==============================] - 115s 330ms/step - loss: -18020.5625 - val_loss: -18124.7500
# Epoch 16/1000
# 349/349 [==============================] - ETA: 0s - loss: -17490.3320
# Epoch 16: val_loss improved from -18226.67773 to -19085.83008, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.16-t-17490.33-v-19085.83.hdf5
# 349/349 [==============================] - 118s 339ms/step - loss: -17490.3320 - val_loss: -19085.8301
# Epoch 17/1000
# 349/349 [==============================] - ETA: 0s - loss: -17276.2754
# Epoch 17: val_loss improved from -19085.83008 to -19414.91016, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.17-t-17276.28-v-19414.91.hdf5
# 349/349 [==============================] - 120s 343ms/step - loss: -17276.2754 - val_loss: -19414.9102
# Epoch 18/1000
# 349/349 [==============================] - ETA: 0s - loss: -18143.5938
# Epoch 18: val_loss did not improve from -19414.91016
# 349/349 [==============================] - 118s 337ms/step - loss: -18143.5938 - val_loss: -19296.6816
# Epoch 19/1000
# 349/349 [==============================] - ETA: 0s - loss: -18503.4121
# Epoch 19: val_loss did not improve from -19414.91016
# 349/349 [==============================] - 114s 327ms/step - loss: -18503.4121 - val_loss: -13570.8926
# Epoch 20/1000
# 349/349 [==============================] - ETA: 0s - loss: -17986.1719
# Epoch 20: val_loss improved from -19414.91016 to -19622.18359, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.20-t-17986.17-v-19622.18.hdf5
# 349/349 [==============================] - 120s 345ms/step - loss: -17986.1719 - val_loss: -19622.1836
# Epoch 21/1000
# 349/349 [==============================] - ETA: 0s - loss: -18576.1914
# Epoch 21: val_loss improved from -19622.18359 to -20079.36133, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.21-t-18576.19-v-20079.36.hdf5
# 349/349 [==============================] - 121s 348ms/step - loss: -18576.1914 - val_loss: -20079.3613
# Epoch 22/1000
# 349/349 [==============================] - ETA: 0s - loss: -18028.5176
# Epoch 22: val_loss did not improve from -20079.36133
# 349/349 [==============================] - 117s 334ms/step - loss: -18028.5176 - val_loss: -19064.4805
# Epoch 23/1000
# 349/349 [==============================] - ETA: 0s - loss: -18483.5117
# Epoch 23: val_loss did not improve from -20079.36133
# 349/349 [==============================] - 125s 358ms/step - loss: -18483.5117 - val_loss: -18901.2500
# Epoch 24/1000
# 349/349 [==============================] - ETA: 0s - loss: -19141.7598
# Epoch 24: val_loss did not improve from -20079.36133
# 349/349 [==============================] - 107s 306ms/step - loss: -19141.7598 - val_loss: -20062.5547
# Epoch 25/1000
# 349/349 [==============================] - ETA: 0s - loss: -19190.9609
# Epoch 25: val_loss did not improve from -20079.36133
# 349/349 [==============================] - 114s 328ms/step - loss: -19190.9609 - val_loss: -19638.8301
# Epoch 26/1000
# 349/349 [==============================] - ETA: 0s - loss: -19204.0586
# Epoch 26: val_loss improved from -20079.36133 to -20235.32227, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.26-t-19204.06-v-20235.32.hdf5
# 349/349 [==============================] - 120s 343ms/step - loss: -19204.0586 - val_loss: -20235.3223
# Epoch 27/1000
# 349/349 [==============================] - ETA: 0s - loss: -19361.4414
# Epoch 27: val_loss did not improve from -20235.32227
# 349/349 [==============================] - 113s 325ms/step - loss: -19361.4414 - val_loss: -18995.0234
# Epoch 28/1000
# 349/349 [==============================] - ETA: 0s - loss: -19954.1719
# Epoch 28: val_loss improved from -20235.32227 to -21305.60742, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.28-t-19954.17-v-21305.61.hdf5
# 349/349 [==============================] - 121s 347ms/step - loss: -19954.1719 - val_loss: -21305.6074
# Epoch 29/1000
# 349/349 [==============================] - ETA: 0s - loss: -20305.0977
# Epoch 29: val_loss did not improve from -21305.60742
# 349/349 [==============================] - 110s 315ms/step - loss: -20305.0977 - val_loss: -19134.0723
# Epoch 30/1000
# 349/349 [==============================] - ETA: 0s - loss: -20212.5039
# Epoch 30: val_loss did not improve from -21305.60742
# 349/349 [==============================] - 81s 233ms/step - loss: -20212.5039 - val_loss: -19186.1973
# Epoch 31/1000
# 349/349 [==============================] - ETA: 0s - loss: -20573.9570
# Epoch 31: val_loss did not improve from -21305.60742
# 349/349 [==============================] - 97s 278ms/step - loss: -20573.9570 - val_loss: -19702.9141
# Epoch 32/1000
# 349/349 [==============================] - ETA: 0s - loss: -20460.0820
# Epoch 32: val_loss did not improve from -21305.60742
# 349/349 [==============================] - 81s 231ms/step - loss: -20460.0820 - val_loss: -21044.4277
# Epoch 33/1000
# 349/349 [==============================] - ETA: 0s - loss: -20731.4121
# Epoch 33: val_loss did not improve from -21305.60742
# 349/349 [==============================] - 72s 207ms/step - loss: -20731.4121 - val_loss: -19828.6680
# Epoch 34/1000
# 349/349 [==============================] - ETA: 0s - loss: -20832.0977
# Epoch 34: val_loss did not improve from -21305.60742
# 349/349 [==============================] - 78s 222ms/step - loss: -20832.0977 - val_loss: -19717.4355
# Epoch 35/1000
# 349/349 [==============================] - ETA: 0s - loss: -20771.6758
# Epoch 35: val_loss did not improve from -21305.60742
# 349/349 [==============================] - 73s 208ms/step - loss: -20771.6758 - val_loss: -19546.9258
# Epoch 36/1000
# 349/349 [==============================] - ETA: 0s - loss: -21129.1426
# Epoch 36: val_loss did not improve from -21305.60742
# 349/349 [==============================] - 79s 225ms/step - loss: -21129.1426 - val_loss: -21143.1836
# Epoch 37/1000
# 349/349 [==============================] - ETA: 0s - loss: -20951.5723
# Epoch 37: val_loss did not improve from -21305.60742
# 349/349 [==============================] - 83s 239ms/step - loss: -20951.5723 - val_loss: -20956.5391
# Epoch 38/1000
# 349/349 [==============================] - ETA: 0s - loss: -20913.5742
# Epoch 38: val_loss improved from -21305.60742 to -21320.19336, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.38-t-20913.57-v-21320.19.hdf5
# 349/349 [==============================] - 78s 223ms/step - loss: -20913.5742 - val_loss: -21320.1934
# Epoch 39/1000
# 349/349 [==============================] - ETA: 0s - loss: -21256.4316
# Epoch 39: val_loss did not improve from -21320.19336
# 349/349 [==============================] - 92s 264ms/step - loss: -21256.4316 - val_loss: -21305.4395
# Epoch 40/1000
# 349/349 [==============================] - ETA: 0s - loss: -21403.2148
# Epoch 40: val_loss improved from -21320.19336 to -21668.66797, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.40-t-21403.21-v-21668.67.hdf5
# 349/349 [==============================] - 84s 242ms/step - loss: -21403.2148 - val_loss: -21668.6680
# Epoch 41/1000
# 349/349 [==============================] - ETA: 0s - loss: -21678.4277
# Epoch 41: val_loss improved from -21668.66797 to -22639.61328, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.41-t-21678.43-v-22639.61.hdf5
# 349/349 [==============================] - 79s 226ms/step - loss: -21678.4277 - val_loss: -22639.6133
# Epoch 42/1000
# 349/349 [==============================] - ETA: 0s - loss: -21229.4238
# Epoch 42: val_loss did not improve from -22639.61328
# 349/349 [==============================] - 94s 269ms/step - loss: -21229.4238 - val_loss: -22272.6816
# Epoch 43/1000
# 349/349 [==============================] - ETA: 0s - loss: -21760.9922
# Epoch 43: val_loss did not improve from -22639.61328
# 349/349 [==============================] - 82s 235ms/step - loss: -21760.9922 - val_loss: -22569.8320
# Epoch 44/1000
# 349/349 [==============================] - ETA: 0s - loss: -21377.3848
# Epoch 44: val_loss did not improve from -22639.61328
# 349/349 [==============================] - 90s 257ms/step - loss: -21377.3848 - val_loss: -22464.1250
# Epoch 45/1000
# 349/349 [==============================] - ETA: 0s - loss: -21796.4609
# Epoch 45: val_loss did not improve from -22639.61328
# 349/349 [==============================] - 92s 262ms/step - loss: -21796.4609 - val_loss: -20585.6836
# Epoch 46/1000
# 349/349 [==============================] - ETA: 0s - loss: -21428.9980
# Epoch 46: val_loss did not improve from -22639.61328
# 349/349 [==============================] - 98s 279ms/step - loss: -21428.9980 - val_loss: -21463.8848
# Epoch 47/1000
# 349/349 [==============================] - ETA: 0s - loss: -21570.0801
# Epoch 47: val_loss did not improve from -22639.61328
# 349/349 [==============================] - 80s 228ms/step - loss: -21570.0801 - val_loss: -21060.9629
# Epoch 48/1000
# 349/349 [==============================] - ETA: 0s - loss: -21440.6367
# Epoch 48: val_loss did not improve from -22639.61328
# 349/349 [==============================] - 93s 268ms/step - loss: -22854.3730 - val_loss: -22330.4297
# Epoch 62/1000
# 349/349 [==============================] - ETA: 0s - loss: -22262.3066
# Epoch 62: val_loss did not improve from -23371.11133
# 349/349 [==============================] - 105s 302ms/step - loss: -22262.3066 - val_loss: -22572.0156
# Epoch 63/1000
# 349/349 [==============================] - ETA: 0s - loss: -22314.1582
# Epoch 63: val_loss did not improve from -23371.11133
# 349/349 [==============================] - 92s 264ms/step - loss: -22314.1582 - val_loss: -21790.9531
# Epoch 64/1000
# 349/349 [==============================] - ETA: 0s - loss: -22561.7500
# Epoch 64: val_loss did not improve from -23371.11133
# 349/349 [==============================] - 96s 276ms/step - loss: -22561.7500 - val_loss: -23082.7285
# Epoch 65/1000
# 349/349 [==============================] - ETA: 0s - loss: -22883.1816
# Epoch 65: val_loss did not improve from -23371.11133
# 349/349 [==============================] - 123s 351ms/step - loss: -22883.1816 - val_loss: -22557.9551
# Epoch 66/1000
# 349/349 [==============================] - ETA: 0s - loss: -22953.7363
# Epoch 66: val_loss did not improve from -23371.11133
# 349/349 [==============================] - 110s 315ms/step - loss: -22953.7363 - val_loss: -22723.0840
# Epoch 67/1000
# 349/349 [==============================] - ETA: 0s - loss: -23231.5508
# Epoch 67: val_loss improved from -23371.11133 to -24406.79883, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.67-t-23231.55-v-24406.80.hdf5
# 349/349 [==============================] - 104s 297ms/step - loss: -23231.5508 - val_loss: -24406.7988
# Epoch 68/1000
# 349/349 [==============================] - ETA: 0s - loss: -23259.5820
# Epoch 68: val_loss did not improve from -24406.79883
# 349/349 [==============================] - 113s 324ms/step - loss: -23259.5820 - val_loss: -23818.8262
# Epoch 69/1000
# 349/349 [==============================] - ETA: 0s - loss: -22385.9277
# Epoch 69: val_loss did not improve from -24406.79883
# 349/349 [==============================] - 104s 298ms/step - loss: -22385.9277 - val_loss: -22409.0254
# Epoch 70/1000
# 349/349 [==============================] - ETA: 0s - loss: -22817.6641
# Epoch 70: val_loss did not improve from -24406.79883
# 349/349 [==============================] - 104s 298ms/step - loss: -22817.6641 - val_loss: -23721.0938
# Epoch 71/1000
# 349/349 [==============================] - ETA: 0s - loss: -23077.0684
# Epoch 71: val_loss did not improve from -24406.79883
# 349/349 [==============================] - 101s 290ms/step - loss: -23077.0684 - val_loss: -23850.6621
# Epoch 72/1000
# 349/349 [==============================] - ETA: 0s - loss: -23148.3809
# Epoch 72: val_loss did not improve from -24406.79883
# 349/349 [==============================] - 95s 273ms/step - loss: -23148.3809 - val_loss: -23084.8418
# Epoch 73/1000
# 349/349 [==============================] - ETA: 0s - loss: -23183.5566
# Epoch 73: val_loss did not improve from -24406.79883
# 349/349 [==============================] - 88s 251ms/step - loss: -23183.5566 - val_loss: -23575.5605
# Epoch 74/1000
# 349/349 [==============================] - ETA: 0s - loss: -23341.9199
# Epoch 74: val_loss did not improve from -24406.79883
# 349/349 [==============================] - 100s 288ms/step - loss: -23341.9199 - val_loss: -23681.3047
# Epoch 75/1000
# 349/349 [==============================] - ETA: 0s - loss: -23491.2969
# Epoch 75: val_loss did not improve from -24406.79883
# 349/349 [==============================] - 84s 242ms/step - loss: -23491.2969 - val_loss: -20626.2793
# Epoch 76/1000
# 349/349 [==============================] - ETA: 0s - loss: -23086.5020
# Epoch 76: val_loss did not improve from -24406.79883
# 349/349 [==============================] - 98s 280ms/step - loss: -23086.5020 - val_loss: -24335.5879
# Epoch 77/1000
# 349/349 [==============================] - ETA: 0s - loss: -23378.5918
# Epoch 77: val_loss did not improve from -24406.79883
# 349/349 [==============================] - 81s 232ms/step - loss: -23378.5918 - val_loss: -24314.7266
# Epoch 78/1000
# 349/349 [==============================] - ETA: 0s - loss: -23661.5156
# Epoch 78: val_loss did not improve from -24406.79883
# 349/349 [==============================] - 91s 260ms/step - loss: -23661.5156 - val_loss: -24158.7031
# Epoch 79/1000
# 349/349 [==============================] - ETA: 0s - loss: -23658.8438
# Epoch 79: val_loss improved from -24406.79883 to -24638.24219, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.79-t-23658.84-v-24638.24.hdf5
# 349/349 [==============================] - 97s 278ms/step - loss: -23658.8438 - val_loss: -24638.2422
# Epoch 80/1000
# 349/349 [==============================] - ETA: 0s - loss: -23906.2656
# Epoch 80: val_loss did not improve from -24638.24219
# 349/349 [==============================] - 77s 222ms/step - loss: -23906.2656 - val_loss: -24208.3105
# Epoch 81/1000
# 349/349 [==============================] - ETA: 0s - loss: -23322.7363
# Epoch 81: val_loss did not improve from -24638.24219
# 349/349 [==============================] - 78s 223ms/step - loss: -23322.7363 - val_loss: -23157.3672
# Epoch 82/1000
# 349/349 [==============================] - ETA: 0s - loss: -23513.8242
# Epoch 82: val_loss improved from -24638.24219 to -24638.98242, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.82-t-23513.82-v-24638.98.hdf5
# 349/349 [==============================] - 78s 224ms/step - loss: -23513.8242 - val_loss: -24638.9824
# Epoch 83/1000
# 349/349 [==============================] - ETA: 0s - loss: -23331.2344
# Epoch 83: val_loss did not improve from -24638.98242
# 349/349 [==============================] - 89s 256ms/step - loss: -23331.2344 - val_loss: -24098.3281
# Epoch 84/1000
# 349/349 [==============================] - ETA: 0s - loss: -23279.5684
# Epoch 84: val_loss did not improve from -24638.98242
# 349/349 [==============================] - 90s 258ms/step - loss: -23279.5684 - val_loss: -23936.5566
# Epoch 85/1000
# 349/349 [==============================] - ETA: 0s - loss: -23544.2793
# Epoch 85: val_loss did not improve from -24638.98242
# 349/349 [==============================] - 91s 260ms/step - loss: -23544.2793 - val_loss: -23437.4062
# Epoch 86/1000
# 349/349 [==============================] - ETA: 0s - loss: -24324.4141
# Epoch 86: val_loss did not improve from -24638.98242
# 349/349 [==============================] - 108s 309ms/step - loss: -24324.4141 - val_loss: -23993.3027
# Epoch 87/1000
# 349/349 [==============================] - ETA: 0s - loss: -24319.6699
# Epoch 87: val_loss improved from -24638.98242 to -25442.13672, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.87-t-24319.67-v-25442.14.hdf5
# 349/349 [==============================] - 89s 254ms/step - loss: -24319.6699 - val_loss: -25442.1367
# Epoch 88/1000
# 349/349 [==============================] - ETA: 0s - loss: -24142.0117
# Epoch 88: val_loss did not improve from -25442.13672
# 349/349 [==============================] - 87s 249ms/step - loss: -24142.0117 - val_loss: -22534.1348
# Epoch 89/1000
# 349/349 [==============================] - ETA: 0s - loss: -24239.0195
# Epoch 89: val_loss did not improve from -25442.13672
# 349/349 [==============================] - 87s 249ms/step - loss: -24239.0195 - val_loss: -24948.0371
# Epoch 90/1000
# 349/349 [==============================] - ETA: 0s - loss: -24500.9238
# Epoch 90: val_loss did not improve from -25442.13672
# 349/349 [==============================] - 94s 271ms/step - loss: -24500.9238 - val_loss: -24872.4414
# Epoch 91/1000
# 349/349 [==============================] - ETA: 0s - loss: -24480.6523
# Epoch 91: val_loss did not improve from -25442.13672
# 349/349 [==============================] - 97s 279ms/step - loss: -24480.6523 - val_loss: -24863.8965
# Epoch 92/1000
# 349/349 [==============================] - ETA: 0s - loss: -24490.0469
# Epoch 92: val_loss did not improve from -25442.13672
# 349/349 [==============================] - 80s 230ms/step - loss: -24490.0469 - val_loss: -25080.4727
# Epoch 93/1000
# 349/349 [==============================] - ETA: 0s - loss: -24051.7109
# Epoch 93: val_loss did not improve from -25442.13672
# 349/349 [==============================] - 81s 233ms/step - loss: -24051.7109 - val_loss: -24117.1699
# Epoch 94/1000
# 349/349 [==============================] - ETA: 0s - loss: -24194.3516
# Epoch 94: val_loss did not improve from -25442.13672
# 349/349 [==============================] - 91s 262ms/step - loss: -24194.3516 - val_loss: -24258.4648
# Epoch 95/1000
# 349/349 [==============================] - ETA: 0s - loss: -24164.7207
# Epoch 95: val_loss did not improve from -25442.13672
# 349/349 [==============================] - 82s 234ms/step - loss: -24164.7207 - val_loss: -23878.8379
# Epoch 96/1000
# 349/349 [==============================] - ETA: 0s - loss: -24275.5566
# Epoch 96: val_loss did not improve from -25442.13672
# 349/349 [==============================] - 84s 242ms/step - loss: -24275.5566 - val_loss: -25317.8730
# Epoch 97/1000
# 349/349 [==============================] - ETA: 0s - loss: -24207.2676
# Epoch 97: val_loss did not improve from -25442.13672
# 349/349 [==============================] - 90s 258ms/step - loss: -24207.2676 - val_loss: -23524.2422
# Epoch 98/1000
# 349/349 [==============================] - ETA: 0s - loss: -24565.5801
# Epoch 98: val_loss did not improve from -25442.13672
# 349/349 [==============================] - 87s 250ms/step - loss: -24565.5801 - val_loss: -25434.9844
# Epoch 99/1000
# 349/349 [==============================] - ETA: 0s - loss: -24406.2422
# Epoch 99: val_loss did not improve from -25442.13672
# 349/349 [==============================] - 86s 248ms/step - loss: -24406.2422 - val_loss: -23314.9844
# Epoch 100/1000
# 349/349 [==============================] - ETA: 0s - loss: -24482.2695
# Epoch 100: val_loss improved from -25442.13672 to -26062.20312, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.100-t-24482.27-v-26062.20.hdf5
# 349/349 [==============================] - 80s 230ms/step - loss: -24482.2695 - val_loss: -26062.2031
# Epoch 101/1000
# 349/349 [==============================] - ETA: 0s - loss: -24531.4727
# Epoch 101: val_loss did not improve from -26062.20312
# 349/349 [==============================] - 87s 250ms/step - loss: -24531.4727 - val_loss: -24827.5488
# Epoch 102/1000
# 349/349 [==============================] - ETA: 0s - loss: -24631.1387
# Epoch 102: val_loss did not improve from -26062.20312
# 349/349 [==============================] - 98s 280ms/step - loss: -24631.1387 - val_loss: -24839.4277
# Epoch 103/1000
# 349/349 [==============================] - ETA: 0s - loss: -24997.7559
# Epoch 103: val_loss did not improve from -26062.20312
# 349/349 [==============================] - 78s 223ms/step - loss: -24997.7559 - val_loss: -25599.9219
# Epoch 104/1000
# 349/349 [==============================] - ETA: 0s - loss: -24863.2109
# Epoch 104: val_loss did not improve from -26062.20312
# 349/349 [==============================] - 80s 230ms/step - loss: -24863.2109 - val_loss: -22878.1836
# Epoch 105/1000
# 349/349 [==============================] - ETA: 0s - loss: -25323.1055
# Epoch 105: val_loss did not improve from -26062.20312
# 349/349 [==============================] - 94s 269ms/step - loss: -25323.1055 - val_loss: -24714.8184
# Epoch 106/1000
# 349/349 [==============================] - ETA: 0s - loss: -25551.6289
# Epoch 106: val_loss did not improve from -26062.20312
# 349/349 [==============================] - 102s 291ms/step - loss: -25551.6289 - val_loss: -25907.4375
# Epoch 107/1000
# 349/349 [==============================] - ETA: 0s - loss: -25424.8906
# Epoch 107: val_loss did not improve from -26062.20312
# 349/349 [==============================] - 78s 224ms/step - loss: -25424.8906 - val_loss: -24645.5859
# Epoch 108/1000
# 349/349 [==============================] - ETA: 0s - loss: -25319.5762
# Epoch 108: val_loss improved from -26062.20312 to -26682.54102, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.108-t-25319.58-v-26682.54.hdf5
# 349/349 [==============================] - 93s 266ms/step - loss: -25319.5762 - val_loss: -26682.5410
# Epoch 109/1000
# 349/349 [==============================] - ETA: 0s - loss: -24925.1250
# Epoch 109: val_loss did not improve from -26682.54102
# 349/349 [==============================] - 84s 240ms/step - loss: -24925.1250 - val_loss: -24886.1191
# Epoch 110/1000
# 349/349 [==============================] - ETA: 0s - loss: -25138.5801
# Epoch 110: val_loss did not improve from -26682.54102
# 349/349 [==============================] - 97s 277ms/step - loss: -25138.5801 - val_loss: -25895.8008
# Epoch 111/1000
# 349/349 [==============================] - ETA: 0s - loss: -25619.7051
# Epoch 111: val_loss did not improve from -26682.54102
# 349/349 [==============================] - 80s 230ms/step - loss: -25619.7051 - val_loss: -24039.4180
# Epoch 112/1000
# 349/349 [==============================] - ETA: 0s - loss: -25458.7793
# Epoch 112: val_loss did not improve from -26682.54102
# 349/349 [==============================] - 87s 249ms/step - loss: -25458.7793 - val_loss: -25888.5684
# Epoch 113/1000
# 349/349 [==============================] - ETA: 0s - loss: -25499.1875
# Epoch 113: val_loss did not improve from -26682.54102
# 349/349 [==============================] - 100s 287ms/step - loss: -25499.1875 - val_loss: -26124.5664
# Epoch 114/1000
# 349/349 [==============================] - ETA: 0s - loss: -25419.1797
# Epoch 114: val_loss did not improve from -26682.54102
# 349/349 [==============================] - 91s 262ms/step - loss: -25419.1797 - val_loss: -25523.5215
# Epoch 115/1000
# 349/349 [==============================] - ETA: 0s - loss: -25721.4766
# Epoch 115: val_loss did not improve from -26682.54102
# 349/349 [==============================] - 79s 226ms/step - loss: -25721.4766 - val_loss: -26534.6387
# Epoch 116/1000
# 349/349 [==============================] - ETA: 0s - loss: -25412.4043
# Epoch 116: val_loss did not improve from -26682.54102
# 349/349 [==============================] - 81s 233ms/step - loss: -25412.4043 - val_loss: -24441.5020
# Epoch 117/1000
# 349/349 [==============================] - ETA: 0s - loss: -25472.0254
# Epoch 117: val_loss did not improve from -26682.54102
# 349/349 [==============================] - 78s 223ms/step - loss: -25472.0254 - val_loss: -24512.8008
# Epoch 118/1000
# 349/349 [==============================] - ETA: 0s - loss: -25296.0137
# Epoch 118: val_loss did not improve from -26682.54102
# 349/349 [==============================] - 82s 234ms/step - loss: -25296.0137 - val_loss: -26210.8242
# Epoch 119/1000
# 349/349 [==============================] - ETA: 0s - loss: -25691.5879
# Epoch 119: val_loss did not improve from -26682.54102
# 349/349 [==============================] - 79s 227ms/step - loss: -25691.5879 - val_loss: -25377.0156
# Epoch 120/1000
# 349/349 [==============================] - ETA: 0s - loss: -25449.5332
# Epoch 120: val_loss improved from -26682.54102 to -26862.48047, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.120-t-25449.53-v-26862.48.hdf5
# 349/349 [==============================] - 81s 233ms/step - loss: -25449.5332 - val_loss: -26862.4805
# Epoch 121/1000
# 349/349 [==============================] - ETA: 0s - loss: -25675.4355
# Epoch 121: val_loss did not improve from -26862.48047
# 349/349 [==============================] - 84s 241ms/step - loss: -25675.4355 - val_loss: -23518.3301
# Epoch 122/1000
# 349/349 [==============================] - ETA: 0s - loss: -25653.5000
# Epoch 122: val_loss did not improve from -26862.48047
# 349/349 [==============================] - 85s 244ms/step - loss: -25653.5000 - val_loss: -26761.8809
# Epoch 123/1000
# 349/349 [==============================] - ETA: 0s - loss: -25855.7500
# Epoch 123: val_loss did not improve from -26862.48047
# 349/349 [==============================] - 103s 294ms/step - loss: -25855.7500 - val_loss: -25309.0176
# Epoch 124/1000
# 349/349 [==============================] - ETA: 0s - loss: -25891.4062
# Epoch 124: val_loss did not improve from -26862.48047
# 349/349 [==============================] - 98s 281ms/step - loss: -25891.4062 - val_loss: -26561.7441
# Epoch 125/1000
# 349/349 [==============================] - ETA: 0s - loss: -25912.6152
# Epoch 125: val_loss did not improve from -26862.48047
# 349/349 [==============================] - 86s 245ms/step - loss: -25912.6152 - val_loss: -26240.9062
# Epoch 126/1000
# 349/349 [==============================] - ETA: 0s - loss: -25790.7637
# Epoch 126: val_loss did not improve from -26862.48047
# 349/349 [==============================] - 87s 248ms/step - loss: -25790.7637 - val_loss: -24753.9023
# Epoch 127/1000
# 349/349 [==============================] - ETA: 0s - loss: -25688.1309
# Epoch 127: val_loss did not improve from -26862.48047
# 349/349 [==============================] - 91s 261ms/step - loss: -25688.1309 - val_loss: -26053.1875
# Epoch 128/1000
# 349/349 [==============================] - ETA: 0s - loss: -25622.9375
# Epoch 128: val_loss did not improve from -26862.48047
# 349/349 [==============================] - 78s 224ms/step - loss: -25622.9375 - val_loss: -26712.5117
# Epoch 129/1000
# 349/349 [==============================] - ETA: 0s - loss: -25716.6699
# Epoch 129: val_loss did not improve from -26862.48047
# 349/349 [==============================] - 83s 239ms/step - loss: -25716.6699 - val_loss: -26740.6543
# Epoch 130/1000
# 349/349 [==============================] - ETA: 0s - loss: -25479.3672
# Epoch 130: val_loss did not improve from -26862.48047
# 349/349 [==============================] - 92s 264ms/step - loss: -25479.3672 - val_loss: -26555.9648
# Epoch 131/1000
# 349/349 [==============================] - ETA: 0s - loss: -25571.0586
# Epoch 131: val_loss did not improve from -26862.48047
# 349/349 [==============================] - 87s 248ms/step - loss: -25571.0586 - val_loss: -23290.6875
# Epoch 132/1000
# 349/349 [==============================] - ETA: 0s - loss: -26072.7266
# Epoch 132: val_loss did not improve from -26862.48047
# 349/349 [==============================] - 97s 278ms/step - loss: -26072.7266 - val_loss: -26120.0293
# Epoch 133/1000
# 349/349 [==============================] - ETA: 0s - loss: -25828.0430
# Epoch 133: val_loss improved from -26862.48047 to -27147.63672, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.133-t-25828.04-v-27147.64.hdf5
# 349/349 [==============================] - 95s 273ms/step - loss: -25828.0430 - val_loss: -27147.6367
# Epoch 134/1000
# 349/349 [==============================] - ETA: 0s - loss: -26138.3496
# Epoch 134: val_loss did not improve from -27147.63672
# 349/349 [==============================] - 102s 293ms/step - loss: -26138.3496 - val_loss: -26992.7520
# Epoch 135/1000
# 349/349 [==============================] - ETA: 0s - loss: -25773.0469
# Epoch 135: val_loss did not improve from -27147.63672
# 349/349 [==============================] - 79s 227ms/step - loss: -25773.0469 - val_loss: -24509.1973
# Epoch 136/1000
# 349/349 [==============================] - ETA: 0s - loss: -25815.6289
# Epoch 136: val_loss did not improve from -27147.63672
# 349/349 [==============================] - 79s 226ms/step - loss: -25815.6289 - val_loss: -26102.8340
# Epoch 137/1000
# 349/349 [==============================] - ETA: 0s - loss: -25764.1465
# Epoch 137: val_loss improved from -27147.63672 to -27412.12695, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.137-t-25764.15-v-27412.13.hdf5
# 349/349 [==============================] - 85s 242ms/step - loss: -25764.1465 - val_loss: -27412.1270
# Epoch 138/1000
# 349/349 [==============================] - ETA: 0s - loss: -26086.7969
# Epoch 138: val_loss did not improve from -27412.12695
# 349/349 [==============================] - 84s 241ms/step - loss: -26086.7969 - val_loss: -25493.9121
# Epoch 139/1000
# 349/349 [==============================] - ETA: 0s - loss: -26279.9258
# Epoch 139: val_loss did not improve from -27412.12695
# 349/349 [==============================] - 104s 297ms/step - loss: -26279.9258 - val_loss: -26000.5332
# Epoch 140/1000
# 349/349 [==============================] - ETA: 0s - loss: -26256.3730
# Epoch 140: val_loss did not improve from -27412.12695
# 349/349 [==============================] - 93s 267ms/step - loss: -26256.3730 - val_loss: -26531.9551
# Epoch 141/1000
# 349/349 [==============================] - ETA: 0s - loss: -26193.5098
# Epoch 141: val_loss did not improve from -27412.12695
# 349/349 [==============================] - 93s 268ms/step - loss: -26193.5098 - val_loss: -27349.3340
# Epoch 142/1000
# 349/349 [==============================] - ETA: 0s - loss: -26199.9512
# Epoch 142: val_loss did not improve from -27412.12695
# 349/349 [==============================] -
val_loss did not improve from -28639.51758
# 349/349 [==============================] - 89s 255ms/step - loss: -26906.8574 - val_loss: -26407.6289
# Epoch 246/1000
# 349/349 [==============================] - ETA: 0s - loss: -27171.6543
# Epoch 246: val_loss did not improve from -28639.51758
# 349/349 [==============================] - 91s 262ms/step - loss: -27171.6543 - val_loss: -27137.4414
# Epoch 247/1000
# 349/349 [==============================] - ETA: 0s - loss: -26739.8359
# Epoch 247: val_loss did not improve from -28639.51758
# 349/349 [==============================] - 79s 228ms/step - loss: -26739.8359 - val_loss: -27096.4746
# Epoch 248/1000
# 349/349 [==============================] - ETA: 0s - loss: -26986.8652
# Epoch 248: val_loss did not improve from -28639.51758
# 349/349 [==============================] - 79s 227ms/step - loss: -26986.8652 - val_loss: -26767.3906
# Epoch 249/1000
# 349/349 [==============================] - ETA: 0s - loss: -27143.4121
# Epoch 249: val_loss did not improve from -28639.51758
# 349/349 [==============================] - 80s 229ms/step - loss: -27143.4121 - val_loss: -27156.4512
# Epoch 250/1000
# 349/349 [==============================] - ETA: 0s - loss: -26974.7344
# Epoch 250: val_loss did not improve from -28639.51758
# 349/349 [==============================] - 84s 242ms/step - loss: -26974.7344 - val_loss: -26124.0781
# Epoch 251/1000
# 349/349 [==============================] - ETA: 0s - loss: -26786.2344
# Epoch 251: val_loss did not improve from -28639.51758
# 349/349 [==============================] - 83s 237ms/step - loss: -26786.2344 - val_loss: -26459.3711
# Epoch 252/1000
# 349/349 [==============================] - ETA: 0s - loss: -26879.1797
# Epoch 252: val_loss did not improve from -28639.51758
# 349/349 [==============================] - 80s 230ms/step - loss: -26879.1797 - val_loss: -26624.5684
# Epoch 253/1000
# 349/349 [==============================] - ETA: 0s - loss: -26976.1484
# Epoch 253: val_loss did not improve from -28639.51758
# 349/349 [==============================] - 79s 228ms/step - loss: -26976.1484 - val_loss: -26642.9395
# Epoch 254/1000
# 349/349 [==============================] - ETA: 0s - loss: -27130.2148
# Epoch 254: val_loss did not improve from -28639.51758
# 349/349 [==============================] - 95s 272ms/step - loss: -27130.2148 - val_loss: -27412.9297
# Epoch 255/1000
# 349/349 [==============================] - ETA: 0s - loss: -27203.7734
# Epoch 255: val_loss did not improve from -28639.51758
# 349/349 [==============================] - 84s 240ms/step - loss: -27203.7734 - val_loss: -27156.7227
# Epoch 256/1000
# 349/349 [==============================] - ETA: 0s - loss: -27352.0508
# Epoch 256: val_loss improved from -28639.51758 to -28704.00781, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.256-t-27352.05-v-28704.01.hdf5
# 349/349 [==============================] - 80s 229ms/step - loss: -27352.0508 - val_loss: -28704.0078
# Epoch 257/1000
# 349/349 [==============================] - ETA: 0s - loss: -27683.6504
# Epoch 257: val_loss did not improve from -28704.00781
# 349/349 [==============================] - 84s 242ms/step - loss: -27683.6504 - val_loss: -26062.9668
# Epoch 258/1000
# 349/349 [==============================] - ETA: 0s - loss: -27964.2168
# Epoch 258: val_loss did not improve from -28704.00781
# 349/349 [==============================] - 98s 282ms/step - loss: -27964.2168 - val_loss: -27448.0938
# Epoch 259/1000
# 349/349 [==============================] - ETA: 0s - loss: -27612.9004
# Epoch 259: val_loss did not improve from -28704.00781
# 349/349 [==============================] - 119s 341ms/step - loss: -27612.9004 - val_loss: -28271.5859
# Epoch 260/1000
# 349/349 [==============================] - ETA: 0s - loss: -27450.6855
# Epoch 260: val_loss did not improve from -28704.00781
# 349/349 [==============================] - 90s 258ms/step - loss: -27450.6855 - val_loss: -25960.8691
# Epoch 261/1000
# 349/349 [==============================] - ETA: 0s - loss: -27271.8398
# Epoch 261: val_loss did not improve from -28704.00781
# 349/349 [==============================] - 88s 251ms/step - loss: -27271.8398 - val_loss: -27432.4922
# Epoch 262/1000
# 349/349 [==============================] - ETA: 0s - loss: -27571.6406
# Epoch 262: val_loss did not improve from -28704.00781
# 349/349 [==============================] - 84s 240ms/step - loss: -27571.6406 - val_loss: -27463.8613
# Epoch 263/1000
# 349/349 [==============================] - ETA: 0s - loss: -27584.7188
# Epoch 263: val_loss did not improve from -28704.00781
# 349/349 [==============================] - 100s 286ms/step - loss: -27584.7188 - val_loss: -27882.5566
# Epoch 264/1000
# 349/349 [==============================] - ETA: 0s - loss: -27585.6660
# Epoch 264: val_loss improved from -28704.00781 to -29079.68555, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.264-t-27585.67-v-29079.69.hdf5
# 349/349 [==============================] - 86s 246ms/step - loss: -27585.6660 - val_loss: -29079.6855
# Epoch 265/1000
# 349/349 [==============================] - ETA: 0s - loss: -27517.6504
# Epoch 265: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 90s 259ms/step - loss: -27517.6504 - val_loss: -27824.0391
# Epoch 266/1000
# 349/349 [==============================] - ETA: 0s - loss: -27419.4395
# Epoch 266: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 80s 230ms/step - loss: -27419.4395 - val_loss: -28330.1348
# Epoch 267/1000
# 349/349 [==============================] - ETA: 0s - loss: -27292.1973
# Epoch 267: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 92s 264ms/step - loss: -27292.1973 - val_loss: -28562.6367
# Epoch 268/1000
# 349/349 [==============================] - ETA: 0s - loss: -27579.3789
# Epoch 268: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 81s 232ms/step - loss: -27579.3789 - val_loss: -23918.6602
# Epoch 269/1000
# 349/349 [==============================] - ETA: 0s - loss: -27768.3848
# Epoch 269: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 91s 261ms/step - loss: -27768.3848 - val_loss: -28038.8301
# Epoch 270/1000
# 349/349 [==============================] - ETA: 0s - loss: -27984.0645
# Epoch 270: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 81s 232ms/step - loss: -27984.0645 - val_loss: -26672.4590
# Epoch 271/1000
# 349/349 [==============================] - ETA: 0s - loss: -27750.5547
# Epoch 271: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 79s 228ms/step - loss: -27750.5547 - val_loss: -27966.5254
# Epoch 272/1000
# 349/349 [==============================] - ETA: 0s - loss: -27562.0586
# Epoch 272: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 91s 260ms/step - loss: -27562.0586 - val_loss: -28577.7520
# Epoch 273/1000
# 349/349 [==============================] - ETA: 0s - loss: -27798.0996
# Epoch 273: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 92s 265ms/step - loss: -27798.0996 - val_loss: -28496.8633
# Epoch 274/1000
# 349/349 [==============================] - ETA: 0s - loss: -27752.2246
# Epoch 274: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 84s 241ms/step - loss: -27752.2246 - val_loss: -28522.4746
# Epoch 275/1000
# 349/349 [==============================] - ETA: 0s - loss: -27815.5039
# Epoch 275: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 79s 226ms/step - loss: -27815.5039 - val_loss: -27438.3184
# Epoch 276/1000
# 349/349 [==============================] - ETA: 0s - loss: -27647.2168
# Epoch 276: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 91s 260ms/step - loss: -27647.2168 - val_loss: -26300.9277
# Epoch 277/1000
# 349/349 [==============================] - ETA: 0s - loss: -27700.3496
# Epoch 277: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 89s 256ms/step - loss: -27700.3496 - val_loss: -28347.7793
# Epoch 278/1000
# 349/349 [==============================] - ETA: 0s - loss: -27645.4844
# Epoch 278: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 82s 235ms/step - loss: -27645.4844 - val_loss: -27492.6484
# Epoch 279/1000
# 349/349 [==============================] - ETA: 0s - loss: -27690.7617
# Epoch 279: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 102s 292ms/step - loss: -27690.7617 - val_loss: -27985.7988
# Epoch 280/1000
# 349/349 [==============================] - ETA: 0s - loss: -27773.1074
# Epoch 280: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 83s 237ms/step - loss: -27773.1074 - val_loss: -26253.1152
# Epoch 281/1000
# 349/349 [==============================] - ETA: 0s - loss: -27541.4492
# Epoch 281: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 80s 230ms/step - loss: -27541.4492 - val_loss: -28055.4668
# Epoch 282/1000
# 349/349 [==============================] - ETA: 0s - loss: -27767.5938
# Epoch 282: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 82s 236ms/step - loss: -27767.5938 - val_loss: -27294.1270
# Epoch 283/1000
# 349/349 [==============================] - ETA: 0s - loss: -27707.5469
# Epoch 283: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 77s 221ms/step - loss: -27707.5469 - val_loss: -26496.0684
# Epoch 284/1000
# 349/349 [==============================] - ETA: 0s - loss: -27597.8867
# Epoch 284: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 84s 241ms/step - loss: -27597.8867 - val_loss: -26868.9492
# Epoch 285/1000
# 349/349 [==============================] - ETA: 0s - loss: -27448.5059
# Epoch 285: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 92s 264ms/step - loss: -27448.5059 - val_loss: -28079.2852
# Epoch 286/1000
# 349/349 [==============================] - ETA: 0s - loss: -27559.2461
# Epoch 286: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 87s 249ms/step - loss: -27559.2461 - val_loss: -27564.0039
# Epoch 287/1000
# 181/349 [==============>...............] - ETA: 32s - loss: -27488.8379
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 349/349 [==============================] - ETA: 0s - loss: -27640.3691
# Epoch 293: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 76s 218ms/step - loss: -27640.3691 - val_loss: -27861.4668
# Epoch 294/1000
# 349/349 [==============================] - ETA: 0s - loss: -27644.4258
# Epoch 294: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 80s 230ms/step - loss: -27644.4258 - val_loss: -27532.1855
# Epoch 295/1000
# 349/349 [==============================] - ETA: 0s - loss: -27472.0117
# Epoch 295: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 80s 229ms/step - loss: -27472.0117 - val_loss: -28884.9922
# Epoch 296/1000
# 349/349 [==============================] - ETA: 0s - loss: -27608.0527
# Epoch 296: val_loss did not improve from -29079.68555
# 349/349 [==============================] - 85s 244ms/step - loss: -27608.0527 - val_loss: -26250.9707
# Epoch 297/1000
# 349/349 [==============================] - ETA: 0s - loss: -27534.5391
# Epoch 297: val_loss improved from -29079.68555 to -29365.89648, saving model to ./trained_models/type6/model-c8fe3c7d-checkpoints/weights.297-t-27534.54-v-29365.90.hdf5
# 349/349 [==============================] - 82s 234ms/step - loss: -27534.5391 - val_loss: -29365.8965
# Epoch 298/1000
# 349/349 [==============================] - ETA: 0s - loss: -27619.1504
# Epoch 298: val_loss did not improve from -29365.89648
# 349/349 [==============================] - 88s 253ms/step - loss: -27619.1504 - val_loss: -26739.0586
# Epoch 299/1000
# 349/349 [==============================] - ETA: 0s - loss: -27647.3320

# %%
# # clean up tf records
# utils.safe_remove_directory(tfrecords_dir_train)
# utils.safe_remove_directory(tfrecords_dir_validation)
